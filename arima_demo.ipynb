# %%
import pmdarima
import arch
import datetime as dt
import quandl
quandl.ApiConfig.api_key = "CdvD4wmxW91pyz4sEciN"

# %%
tic = "AMD"

# Construct 1 year timeframe
d = dt.datetime.today()
ed = d.strftime("%Y-%m-%d")
sd = (d - dt.timedelta(days=365)).strftime("%Y-%m-%d")

# Quandl API
dat = quandl.get_table("QUOTEMEDIA/PRICES", ticker=tic, date={"gte": sd, "lte": ed})
dat
# Out:
#      ticker       date     open      high     low   close      volume  \
# None
# 0       AMD 2021-09-10  106.990  106.9913  104.98  105.20  32177941.0
# 1       AMD 2021-09-09  106.560  107.2953  105.84  106.15  31282822.0
# 2       AMD 2021-09-08  108.880  109.3000  105.52  106.17  42652179.0
# 3       AMD 2021-09-07  109.955  110.5800  108.66  109.15  28644688.0
# 4       AMD 2021-09-03  108.850  111.1700  108.50  109.92  42155501.0
# ...     ...        ...      ...       ...     ...     ...         ...
# 247     AMD 2020-09-17   74.880   76.6250   74.20   76.55  55503348.0
# 248     AMD 2020-09-16   79.350   79.7200   76.54   76.66  38324452.0
# 249     AMD 2020-09-15   77.660   80.3300   75.97   78.93  57767284.0
# 250     AMD 2020-09-14   76.800   78.8200   76.26   77.90  47334352.0
# 251     AMD 2020-09-11   79.820   79.9900   75.04   76.34  54762990.0
#
#       dividend  split  adj_open  adj_high  adj_low  adj_close  adj_volume
# None
# ...
