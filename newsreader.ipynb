# %%
import pandas as pd
import datetime as dt
from time import sleep
from random import randint
import re

# %%
d = dt.datetime.utcnow()
d = d.replace(hour=0, minute=0, second=0, microsecond=0)
d -= dt.timedelta(days=d.weekday())
df = pd.DataFrame()

for i in range(4):
    url = f"https://us.econoday.com/byweek.asp?day={d.day:02d}&month={d.month:02d}&year={d.year}&cust=us&lid=0"
    print(url)
    dl = pd.read_html(url)[6] # The calendar is always at index 6
    dl.columns = [d + dt.timedelta(i) for i in range(5)]
    
    df = pd.concat([df, dl.reset_index(drop=True)], axis=1)
    d += dt.timedelta(days=7)
    sleep(randint(0,10))

df
# Out:
# https://us.econoday.com/byweek.asp?day=04&month=10&year=2021&cust=us&lid=0
# https://us.econoday.com/byweek.asp?day=11&month=10&year=2021&cust=us&lid=0
# https://us.econoday.com/byweek.asp?day=18&month=10&year=2021&cust=us&lid=0
# https://us.econoday.com/byweek.asp?day=25&month=10&year=2021&cust=us&lid=0
#                                           2021-10-04  \
# 0                                       Monday Oct 4
# 1  Market Focus »Market Reflections »Global Econo...
# 2                      U.S. Equity Settlement10-6-21
# 3                                                NaN
# 4                                                NaN
#
#                                           2021-10-05  \
# 0                                      Tuesday Oct 5
# 1  4-Week Bill Settlement8-Week Bill SettlementIn...
# 2                      U.S. Equity Settlement10-7-21
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
process = {}

for c in df.columns:
    splat = re.split("\xa0»|\xa0ET|\xa0", df.loc[1,c])
    
    _ = []
    for l in splat:
        _ += re.findall(".*?Settlement", l) + [s for s in re.split(".*?Settlement", l) if s]
    
    __ = []
    for l in _:
        event = re.split(r'[0-9]{1,2}:[0-9]{2} ', l)
        time = re.findall(r'[0-9]{1,2}:[0-9]{2}', l)
        if time:
            __.append((event[0], time[0], event[1]))
        else:
            __.append((event[0], '*', '*'))
    
    process[c] = __

# %%
process
# Out:
# {Timestamp('2021-10-04 00:00:00'): [('Market Focus', '*', '*'),
#   ('Market Reflections', '*', '*'),
#   ('Global Economics', '*', '*'),
#   ('Motor Vehicle Sales', '*', '*'),
#   ('Eric Rosengren Speaks', '10:00', 'AM'),
#   ('James Bullard Speaks', '10:00', 'AM'),
#   ('Kenneth Montgomery Speaks', '10:00', 'AM'),
#   ('Factory Orders', '10:00', 'AM'),
#   ('3-Month Bill Auction', '11:30', 'AM'),
#   ('6-Month Bill Auction', '11:30', 'AM'),
#   ('Investor Movement Index', '12:30', 'PM')],
#  Timestamp('2021-10-05 00:00:00'): [('4-Week Bill Settlement', '*', '*'),
#   ('8-Week Bill Settlement', '*', '*'),
#   ('International Trade in Goods and Services', '8:30', 'AM'),
#   ('Redbook', '8:55', 'AM'),
#   ('PMI Composite Final', '9:45', 'AM'),
#   ('ISM Services Index', '10:00', 'AM'),
#   ('Thomas Barkin Speaks', '10:30', 'AM'),
#   ('4-Week Bill Announcement', '11:00', 'AM'),
#   ('8-Week Bill Announcement', '11:00', 'AM'),
#   ('52-Week Bill Auction', '11:30', 'AM'),
# ...

# %%
for k, v in process.items():
# Out:
# 10

# %%
import datetime
from datetime import datetime, timedelta
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/calendar']

CREDENTIALS_FILE = 'token.json'

def get_calendar_service():
   creds = None
   # The file token.pickle stores the user's access and refresh tokens, and is
   # created automatically when the authorization flow completes for the first
   # time.
   if os.path.exists('token.pickle'):
       with open('token.pickle', 'rb') as token:
           creds = pickle.load(token)
   # If there are no (valid) credentials available, let the user log in.
   if not creds or not creds.valid:
       if creds and creds.expired and creds.refresh_token:
           creds.refresh(Request())
       else:
           flow = InstalledAppFlow.from_client_secrets_file(
               CREDENTIALS_FILE, SCOPES)
           creds = flow.run_local_server(port=0)

       # Save the credentials for the next run
       with open('token.pickle', 'wb') as token:
           pickle.dump(creds, token)

   service = build('calendar', 'v3', credentials=creds)
   return service

def main():
   # creates one hour event tomorrow 10 AM IST
   service = get_calendar_service()

   d = datetime.now().date()
   tomorrow = datetime(d.year, d.month, d.day, 10)+timedelta(days=1)
   start = tomorrow.isoformat()
   end = (tomorrow + timedelta(hours=1)).isoformat()

   event_result = service.events().insert(calendarId='primary',
       body={
           "summary": 'Automating calendar',
           "description": 'This is a tutorial example of automating google calendar with python',
           "start": {"dateTime": start, "timeZone": 'Asia/Kolkata'},
           "end": {"dateTime": end, "timeZone": 'Asia/Kolkata'},
       }
   ).execute()

   print("created event")
   print("id: ", event_result['id'])
   print("summary: ", event_result['summary'])
   print("starts at: ", event_result['start']['dateTime'])
   print("ends at: ", event_result['end']['dateTime'])

if __name__ == '__main__':
   main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=563195782848-0o5gnckjj9q6mjm2ug1gch1vphstuunm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A52255%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=Apo4ZETs6LVX4Aa2yO5IvLEmMhVtw0&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16399/1201691647.py in <module>
#      61
#      62 if __name__ == '__main__':
# ---> 63    main()
#
# /tmp/ipykernel_16399/1201691647.py in main()
#      38 def main():
#      39    # creates one hour event tomorrow 10 AM IST
# ---> 40    service = get_calendar_service()
#      41
#      42    d = datetime.now().date()
#
# /tmp/ipykernel_16399/1201691647.py in get_calendar_service()
#      27            flow = InstalledAppFlow.from_client_secrets_file(
# ...

# %%
from __future__ import print_function
import datetime
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']


def main():
    """Shows basic usage of the Google Calendar API.
    Prints the start and name of the next 10 events on the user's calendar.
    """
    creds = None
    
    token_path = "token.json"
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists(token_path):
        creds = Credentials.from_authorized_user_file(token_path, SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open(token_path, 'w') as token:
            token.write(creds.to_json())

    service = build('calendar', 'v3', credentials=creds)

    # Call the Calendar API
    now = datetime.datetime.utcnow().isoformat() + 'Z' # 'Z' indicates UTC time
    print('Getting the upcoming 10 events')
    events_result = service.events().list(calendarId='primary', timeMin=now,
                                        maxResults=10, singleEvents=True,
                                        orderBy='startTime').execute()
    events = events_result.get('items', [])

    if not events:
        print('No upcoming events found.')
    for event in events:
        start = event['start'].get('dateTime', event['start'].get('date'))
        print(start, event['summary'])


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_16399/2704339560.py in <module>
#      53
#      54 if __name__ == '__main__':
# ---> 55     main()
#
# /tmp/ipykernel_16399/2704339560.py in main()
#      22     # time.
#      23     if os.path.exists(token_path):
# ---> 24         creds = Credentials.from_authorized_user_file(token_path, SCOPES)
#      25     # If there are no (valid) credentials available, let the user log in.
#      26     if not creds or not creds.valid:
#
# ~/miniconda3/envs/finmath/lib/python3.9/site-packages/google/oauth2/credentials.py in from_authorized_user_file(cls, filename, scopes)
#     398         with io.open(filename, "r", encoding="utf-8") as json_file:
#     399             data = json.load(json_file)
# --> 400             return cls.from_authorized_user_info(data, scopes)
#     401
#     402     def to_json(self, strip=None):
# ...
